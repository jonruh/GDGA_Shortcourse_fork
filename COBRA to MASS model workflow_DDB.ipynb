# %% [markdown]
# # E. coli Glycolytic Network Construction
# ## Growth Medium: Glucose
# Growth data obtained from the following sources:
# - Gerosa, Luca et al. “Pseudo-transition Analysis Identifies the Key Regulators of Dynamic Metabolic Adaptations from Steady-State Data.” Cell systems vol. 1,4 (2015): 270-82. doi:10.1016/j.cels.2015.09.008
#
#
# - Volkmer, Benjamin, and Matthias Heinemann. “Condition-dependent cell volume and concentration of Escherichia coli to facilitate data conversion for systems biology modeling.” PloS one vol. 6,7 (2011): e23126. doi:10.1371/journal.pone.0023126
#
#
# ### Import packages

# %%
# Disable gurobi logging output for this notebook.
try:
    import gurobipy
    gurobipy.setParam("OutputFlag", 0)
except ImportError:
    pass


import numpy as np
import pandas as pd
import sympy as sym
import matplotlib.pyplot as plt

import cobra
from cobra.io.json import load_json_model as load_cobra_json_model

import mass
from mass import MassConfiguration, MassModel, MassMetabolite, MassReaction, Simulation
from mass.io.json import save_json_model as save_mass_json_model
from mass.visualization import plot_comparison, plot_time_profile


print(f"COBRApy version: {cobra.__version__}")
print(f"MASSpy version: {mass.__version__}")
# Out:
# Academic license - for non-commercial use only - expires 2022-09-24
# Using license file C:\Users\dczie\gurobi.lic
# COBRApy version: 0.22.1
# MASSpy version: 0.1.6

# %% [markdown]
# ### Set solver

# %%
MASSCONFIGURATION = MassConfiguration()
MASSCONFIGURATION.solver = "gurobi"

# %% [markdown]
# ## Load COBRA model

# %%
cobra_model = load_cobra_json_model(f"./models/cobra/iML1515.json")

# %% [markdown]
# ## Obtain Flux State
# ### Load growth data

# %%
medium = "Glucose"
'''
flux_data = pd.read_excel(
    io="./data/growth_data_extended.xlsx",
    sheet_name="flux_data",
    index_col=0
)
'''
flux_data = pd.read_excel(
    io="./data/growth_data_extended.xlsx",
    sheet_name="flux_data_reduced",
    index_col=0
)
flux_data = flux_data.loc[lambda x: x['Growth Medium'] == medium]
flux_data = flux_data.drop("Growth Medium", axis=1)
flux_data
# Out:
#                               Flux (mmol * gDW-1 * h-1)
# Rxn
# GLCptspp                                       9.613287
# PGI                                            5.698950
# PFK                                            7.057500
# FBP                                            0.000000
# FBA                                            7.057500
# ...                                                 ...
# L_LACD2                                        0.000000
# CYTBO3_4pp                                    38.191466
# CYTBDpp                                        0.000000
# BIOMASS_Ec_iML1515_WT_75p37M                   0.455339
# EX_glc__D_e                                   -9.655000
#
# [75 rows x 1 columns]

# %% [markdown]
# ### Set bounds
# #### Growth rate and media

# %%
biomass_rxn = cobra_model.reactions.BIOMASS_Ec_iML1515_WT_75p37M
growth_rate = flux_data.loc[biomass_rxn.id][0] #This index is hard-coded based on which column has the flux value
biomass_rxn.bounds = (0, growth_rate)
biomass_rxn.bounds
# Out:
# (0, 0.455338783207954)

# %%
EX_glc__D_e = cobra_model.reactions.EX_glc__D_e
medium_uptake = flux_data.loc[EX_glc__D_e.id][0] #This index is hard-coded based on which column has the flux value
EX_glc__D_e.bounds = (medium_uptake, 0)
EX_glc__D_e.bounds
# Out:
# (-9.655, 0)

# %% [markdown]
# ### Formulate QP minimization for fluxes

# %%
v_vars = []
v_data = []

# For irreversible enzyme pairs, flux data is given as Enzyme1 - Enzyme2 = value.
# To ensure all enzymes have some flux, add a percentage of the net flux for each enzyme
# The netflux will still remain the same value.
reverse_flux_percent = 0.1

irreversible_enzyme_pairs = [["PFK", "FBP"], ["PYK", "PPS"]]

for rid, flux in flux_data.itertuples():
    # Make adjustments to net flux of PFK/FBP and PYK/PPS to ensure
    # no target flux value is 0 in order to create an enzyme module.
    for irreversible_enzyme_pair in irreversible_enzyme_pairs:
        
        if rid in irreversible_enzyme_pair:
            flux1, flux2 = flux_data.loc[irreversible_enzyme_pair, "Flux (mmol * gDW-1 * h-1)"].values
            if flux1 == 0:
                flux += reverse_flux_percent * flux2 # mmol*gDW^-1*hr^-1
            if flux2 == 0:
                flux += reverse_flux_percent * flux1 # mmol*gDW^-1*hr^-1
            print(rid, flux)
            
    v_vars.append(sym.Symbol(rid))
    v_data.append(flux)

# Make symbolic for optlang objective 
v_vars = sym.Matrix(v_vars)
v_data = sym.Matrix(v_data)
F = sym.Matrix(2 * sym.eye(len(v_vars)))

objective = 0.5 * v_vars.T * F * v_vars  - (2 * v_data).T * v_vars
cobra_model.objective = objective[0]
cobra_model.objective_direction = "min"

flux_solution = cobra_model.optimize()
flux_solution
# Out:
# PFK 7.76325
# FBP 0.7057500000000001
# PYK 2.73493
# PPS 0.24863000000000002
# <Solution -9305.852 at 0x2510e5025b0>

# %%
flux_comparison_fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(5, 5))
plot_comparison(
    x=flux_data["Flux (mmol * gDW-1 * h-1)"], y=flux_solution, compare="fluxes",
    observable=[rid for rid in flux_data.index], ax=ax,
    legend="right outside", plot_function="plot",
    xlim=(-16.5, 16.5), ylim=(-16.5, 16.5),
    xy_line=True,
    xy_legend="best", xlabel="Measured [mmol/(gDW * h)]", ylabel="Adjusted [mmol/(gDW * h)]")

flux_comparison_fig.tight_layout()

# %% [markdown]
# #### Export data for analysis

# %%
flux_data_for_comparison = pd.concat(objs=(flux_data, flux_solution.fluxes), axis=1).dropna()
flux_data_for_comparison.index.name = "ID"
flux_data_for_comparison.columns = ["Initial", "Adjusted"]
flux_data_for_comparison.to_csv("./data/analysis_data/fluxes_extended.csv")

# %% [markdown]
# ## Create MASS Model

# %%
# Create MassModel
mass_model = MassModel("CentralMetabolism", array_type="DataFrame")

# Reactions to extract into subnetwork
reaction_list = [
    "GLCptspp",
"PGI",
"PFK",
"FBP",
"FBA",
"TPI",
"GAPD",
"PGK",
"PGM",
"ENO",
"PYK",
"PPS",
"G6PDH2r",
"PGL",
"GND",
"RPE",
"RPI",
"TKT1",
"TKT2",
"TALA",
"LDH_D",
"D_LACt2pp",
"PYRt2rpp",
"PFL",
"PTAr",
"ACKr",
"ACt2rpp",
"ACALD",
"ACALDtpp",
"ALCD2x",
"ETOHtrpp",
"PDH",
"OAADC",
"PPC",
"PPCK",
"ME1",
"ME2",
"SUCCt1pp",
"AKGt2rpp",
"CS",
"ACONTa",
"ACONTb",
"ICDHyr",
"AKGDH",
"SUCOAS",
"SUCDi",
"FUM",
"MDH",
"MDH2",
"ICL",
"MALS",
"PGMT",
"G3PD2",
"HCO3E",
"CO2tpp",
"PPA",
"CAT",
"SPODM",
"SPODMpp",
"ATPM",
"ATPS4rpp",
"THD2pp",
"NADTRHD",
"NADH16pp",
"FDH4pp",
"NADPHQR2",
"NADH5",
"LDH_D2",
"POX",
"G3PD5",
"L_LACD2",
"CYTBO3_4pp",
"CYTBDpp",
]

cobra_reactions = cobra_model.reactions.get_by_any(reaction_list)
mass_model.add_reactions([MassReaction(rxn) for rxn in cobra_reactions])
mass_model
# Out:
# <MassModel CentralMetabolism at 0x251106c4f70>

# %% [markdown]
# ### Convert flux units to M/s

# %%
T = 313.15
gas_constant = 0.008314
e_coli_density = 1.1 # g / mL assumption
volume = 3.2  # femtoliter

# Perform conversions
doubling_time_per_minute = np.log(2) / growth_rate * 60
cell_gDW = 42000 * doubling_time_per_minute**-1.232 * 1e-15
real_cell_total_weight = e_coli_density * (volume * 1e-12) # fL --> mL

# Assume water is 70%
adj_volume = volume * 0.7
gDW_L_conversion_factor = real_cell_total_weight / (adj_volume * 1e-15)

for reaction in mass_model.reactions.get_by_any(reaction_list):
    flux = flux_solution[reaction.id]
    reaction.steady_state_flux = flux * gDW_L_conversion_factor * 0.001 / 3600

# %% [markdown]
# ## Set equilibrium constants

# %%
Keq_data = pd.read_excel(
    io="./data/growth_data_extended.xlsx",
    sheet_name="Keq_data",
    index_col=0
)
for reaction in mass_model.reactions.get_by_any(reaction_list):
    reaction.Keq = Keq_data.loc[reaction.Keq_str][0]

# %%
conc_data = pd.read_excel(
    io="./data/growth_data_extended.xlsx",
    sheet_name="conc_data",
    index_col=0
)
conc_data = conc_data.loc[lambda x: x['Growth Medium'] == "Glucose"]
conc_data = conc_data.drop("Growth Medium", axis=1)
conc_data
# Out:
#            Concentration (mol * L-1)
# ID
# 10fthf_c                1.051286e-04
# 13dpg_c                 5.507545e-05
# 23dhb_c                 1.380000e-04
# 2ddg6p_c                1.247644e-05
# 2dmmql8                 1.051286e-04
# ...                              ...
# utp_c                   8.290000e-03
# val__L_c                4.020000e-03
# xu5p__D_c               6.447318e-04
# h_c                     3.162278e-08
# h2o_c                   1.000000e+00
#
# [171 rows x 1 columns]

# %% [markdown]
# ### Add PFK1 activator GDP

# %%
#gdp_c = MassMetabolite(cobra_model.metabolites.gdp_c)
# Set the activator as a constant
#gdp_c.fixed = True

#mass_model.add_metabolites(gdp_c)

# %% [markdown]
# ### Set initial concentrations from growth data

# %%
mass_model.update_initial_conditions({
    mid: value for mid, value in conc_data.itertuples()
})

# Fix hydrogen and water as constants and set concentration to 1.
for metabolite in mass_model.metabolites.get_by_any(["h2o_c", "h_c"]):
    metabolite.fixed = True
    metabolite.initial_condition = 1

missing_ics = mass_model.metabolites.query(lambda m: m.initial_condition is None)
# Provide initial guesses for missing metabolites (pi_c, g3p_c, and lac__D_c)
print(missing_ics)
for metabolite in missing_ics:
    metabolite.initial_condition = 0.001
# Out:
# [<MassMetabolite glc__D_p at 0x251106e34c0>, <MassMetabolite 6pgl_c at 0x251106da4c0>, <MassMetabolite lac__D_c at 0x251106ec970>, <MassMetabolite h_p at 0x251106ecaf0>, <MassMetabolite lac__D_p at 0x251106ecbb0>, <MassMetabolite pyr_p at 0x251106ecd30>, <MassMetabolite ac_p at 0x251106e95b0>, <MassMetabolite acald_c at 0x251106e9730>, <MassMetabolite acald_p at 0x251106e9970>, <MassMetabolite etoh_c at 0x251106e99a0>, <MassMetabolite etoh_p at 0x251106e9ca0>, <MassMetabolite succ_p at 0x251106dc8e0>, <MassMetabolite akg_p at 0x251106dc9a0>, <MassMetabolite glx_c at 0x251106dde80>, <MassMetabolite co2_p at 0x251106df7c0>, <MassMetabolite h2o2_c at 0x251106dfa60>, <MassMetabolite o2s_c at 0x251106dfd00>, <MassMetabolite h2o2_p at 0x251106dfe50>, <MassMetabolite o2_p at 0x251106dff70>, <MassMetabolite o2s_p at 0x251106dfee0>, <MassMetabolite for_p at 0x251106e0c10>, <MassMetabolite lac__L_c at 0x251106e2e50>]
# mass\core\mass_model.py:1967 UserWarning: No metabolite found for '10fthf_c'
# mass\core\mass_model.py:1967 UserWarning: No metabolite found for '23dhb_c'
# mass\core\mass_model.py:1967 UserWarning: No metabolite found for '2ddg6p_c'
# mass\core\mass_model.py:1967 UserWarning: No metabolite found for '2dmmql8'
# mass\core\mass_model.py:1967 UserWarning: No metabolite found for '2dr5p_c'
# mass\core\mass_model.py:1967 UserWarning: No metabolite found for '4abut_c'
# mass\core\mass_model.py:1967 UserWarning: No metabolite found for '4hbz_c'
# mass\core\mass_model.py:1967 UserWarning: No metabolite found for '5mthf'
# mass\core\mass_model.py:1967 UserWarning: No metabolite found for 'aacoa_c'
# mass\core\mass_model.py:1967 UserWarning: No metabolite found for 'acgam1p_c'
# mass\core\mass_model.py:1967 UserWarning: No metabolite found for 'acorn_c'
# mass\core\mass_model.py:1967 UserWarning: No metabolite found for 'ade_c'
# mass\core\mass_model.py:1967 UserWarning: No metabolite found for 'adn_c'
# mass\core\mass_model.py:1967 UserWarning: No metabolite found for 'adocbl'
# mass\core\mass_model.py:1967 UserWarning: No metabolite found for 'adpglc_c'
# mass\core\mass_model.py:1967 UserWarning: No metabolite found for 'agm_c'
# mass\core\mass_model.py:1967 UserWarning: No metabolite found for 'ala__L_c'
# mass\core\mass_model.py:1967 UserWarning: No metabolite found for 'ala_B_c'
# mass\core\mass_model.py:1967 UserWarning: No metabolite found for 'amet_c'
# mass\core\mass_model.py:1967 UserWarning: No metabolite found for 'anth_c'
# mass\core\mass_model.py:1967 UserWarning: No metabolite found for 'aps_c'
# mass\core\mass_model.py:1967 UserWarning: No metabolite found for 'arg__L_c'
# mass\core\mass_model.py:1967 UserWarning: No metabolite found for 'asn__L_c'
# mass\core\mass_model.py:1967 UserWarning: No metabolite found for 'asp__L_c'
# mass\core\mass_model.py:1967 UserWarning: No metabolite found for 'btn'
# mass\core\mass_model.py:1967 UserWarning: No metabolite found for 'camp_c'
# mass\core\mass_model.py:1967 UserWarning: No metabolite found for 'cbasp_c'
# mass\core\mass_model.py:1967 UserWarning: No metabolite found for 'chor'
# mass\core\mass_model.py:1967 UserWarning: No metabolite found for 'citr__L_c'
# mass\core\mass_model.py:1967 UserWarning: No metabolite found for 'clpn160'
# mass\core\mass_model.py:1967 UserWarning: No metabolite found for 'clpn161'
# mass\core\mass_model.py:1967 UserWarning: No metabolite found for 'clpn181'
# mass\core\mass_model.py:1967 UserWarning: No metabolite found for 'cmp_c'
# mass\core\mass_model.py:1967 UserWarning: No metabolite found for 'crn_c'
# mass\core\mass_model.py:1967 UserWarning: No metabolite found for 'csn_c'
# mass\core\mass_model.py:1967 UserWarning: No metabolite found for 'ctp_c'
# mass\core\mass_model.py:1967 UserWarning: No metabolite found for 'cys__L_c'
# mass\core\mass_model.py:1967 UserWarning: No metabolite found for 'cytd_c'
# mass\core\mass_model.py:1967 UserWarning: No metabolite found for 'dad_2_c'
# mass\core\mass_model.py:1967 UserWarning: No metabolite found for 'damp_c'
# mass\core\mass_model.py:1967 UserWarning: No metabolite found for 'datp_c'
# mass\core\mass_model.py:1967 UserWarning: No metabolite found for 'dctp_c'
# mass\core\mass_model.py:1967 UserWarning: No metabolite found for 'dgmp_c'
# mass\core\mass_model.py:1967 UserWarning: No metabolite found for 'dgsn_c'
# mass\core\mass_model.py:1967 UserWarning: No metabolite found for 'dhor__S_c'
# mass\core\mass_model.py:1967 UserWarning: No metabolite found for 'dtdp_c'
# mass\core\mass_model.py:1967 UserWarning: No metabolite found for 'dttp_c'
# mass\core\mass_model.py:1967 UserWarning: No metabolite found for 'enter'
# mass\core\mass_model.py:1967 UserWarning: No metabolite found for 'f1p_c'
# mass\core\mass_model.py:1967 UserWarning: No metabolite found for 'fad_c'
# mass\core\mass_model.py:1967 UserWarning: No metabolite found for 'fmn_c'
# mass\core\mass_model.py:1967 UserWarning: No metabolite found for 'gal1p_c'
# mass\core\mass_model.py:1967 UserWarning: No metabolite found for 'gam6p_c'
# mass\core\mass_model.py:1967 UserWarning: No metabolite found for 'gdp_c'
# mass\core\mass_model.py:1967 UserWarning: No metabolite found for 'glcn_c'
# mass\core\mass_model.py:1967 UserWarning: No metabolite found for 'gln__L_c'
# mass\core\mass_model.py:1967 UserWarning: No metabolite found for 'glu__L_c'
# mass\core\mass_model.py:1967 UserWarning: No metabolite found for 'gly_c'
# mass\core\mass_model.py:1967 UserWarning: No metabolite found for 'glyc__R_c'
# mass\core\mass_model.py:1967 UserWarning: No metabolite found for 'gmp_c'
# mass\core\mass_model.py:1967 UserWarning: No metabolite found for 'gsn_c'
# mass\core\mass_model.py:1967 UserWarning: No metabolite found for 'gthox_c'
# mass\core\mass_model.py:1967 UserWarning: No metabolite found for 'gthrd_c'
# mass\core\mass_model.py:1967 UserWarning: No metabolite found for 'gtp_c'
# mass\core\mass_model.py:1967 UserWarning: No metabolite found for 'gua_c'
# mass\core\mass_model.py:1967 UserWarning: No metabolite found for 'hcys__L_c'
# mass\core\mass_model.py:1967 UserWarning: No metabolite found for 'hemeO'
# mass\core\mass_model.py:1967 UserWarning: No metabolite found for 'his__L_c'
# mass\core\mass_model.py:1967 UserWarning: No metabolite found for 'histd_c'
# mass\core\mass_model.py:1967 UserWarning: No metabolite found for 'hom__L_c'
# mass\core\mass_model.py:1967 UserWarning: No metabolite found for 'hxan_c'
# mass\core\mass_model.py:1967 UserWarning: No metabolite found for 'idp_c'
# mass\core\mass_model.py:1967 UserWarning: No metabolite found for 'ile__L_c'
# mass\core\mass_model.py:1967 UserWarning: No metabolite found for 'imp_c'
# mass\core\mass_model.py:1967 UserWarning: No metabolite found for 'inost_c'
# mass\core\mass_model.py:1967 UserWarning: No metabolite found for 'itp_c'
# mass\core\mass_model.py:1967 UserWarning: No metabolite found for 'leu__L_c'
# mass\core\mass_model.py:1967 UserWarning: No metabolite found for 'lys__L_c'
# mass\core\mass_model.py:1967 UserWarning: No metabolite found for 'malcoa'
# mass\core\mass_model.py:1967 UserWarning: No metabolite found for 'man6p_c'
# mass\core\mass_model.py:1967 UserWarning: No metabolite found for 'met__L_c'
# mass\core\mass_model.py:1967 UserWarning: No metabolite found for 'mlthf'
# mass\core\mass_model.py:1967 UserWarning: No metabolite found for 'mnl1p_c'
# mass\core\mass_model.py:1967 UserWarning: No metabolite found for 'mobd'
# mass\core\mass_model.py:1967 UserWarning: No metabolite found for 'mococdp'
# mass\core\mass_model.py:1967 UserWarning: No metabolite found for 'mocogdp'
# mass\core\mass_model.py:1967 UserWarning: No metabolite found for 'mql8'
# mass\core\mass_model.py:1967 UserWarning: No metabolite found for 'nh4_c'
# mass\core\mass_model.py:1967 UserWarning: No metabolite found for 'orn_c'
# mass\core\mass_model.py:1967 UserWarning: No metabolite found for 'pe160'
# mass\core\mass_model.py:1967 UserWarning: No metabolite found for 'pe161'
# mass\core\mass_model.py:1967 UserWarning: No metabolite found for 'pe181'
# mass\core\mass_model.py:1967 UserWarning: No metabolite found for 'pg160'
# mass\core\mass_model.py:1967 UserWarning: No metabolite found for 'pg161'
# mass\core\mass_model.py:1967 UserWarning: No metabolite found for 'pg181'
# mass\core\mass_model.py:1967 UserWarning: No metabolite found for 'phe__L_c'
# mass\core\mass_model.py:1967 UserWarning: No metabolite found for 'pheme'
# mass\core\mass_model.py:1967 UserWarning: No metabolite found for 'phpyr_c'
# mass\core\mass_model.py:1967 UserWarning: No metabolite found for 'pro__L_c'
# mass\core\mass_model.py:1967 UserWarning: No metabolite found for 'prpp_c'
# mass\core\mass_model.py:1967 UserWarning: No metabolite found for 'ptrc_c'
# mass\core\mass_model.py:1967 UserWarning: No metabolite found for 'pydx5p'
# mass\core\mass_model.py:1967 UserWarning: No metabolite found for 'quln_c'
# mass\core\mass_model.py:1967 UserWarning: No metabolite found for 'ribflv_c'
# mass\core\mass_model.py:1967 UserWarning: No metabolite found for 'sarcs_c'
# mass\core\mass_model.py:1967 UserWarning: No metabolite found for 'ser__L_c'
# mass\core\mass_model.py:1967 UserWarning: No metabolite found for 'sheme'
# mass\core\mass_model.py:1967 UserWarning: No metabolite found for 'skm_c'
# mass\core\mass_model.py:1967 UserWarning: No metabolite found for 'spmd_c'
# mass\core\mass_model.py:1967 UserWarning: No metabolite found for 'thf'
# mass\core\mass_model.py:1967 UserWarning: No metabolite found for 'thmpp'
# mass\core\mass_model.py:1967 UserWarning: No metabolite found for 'thr__L_c'
# mass\core\mass_model.py:1967 UserWarning: No metabolite found for 'tre6p_c'
# mass\core\mass_model.py:1967 UserWarning: No metabolite found for 'trp__L_c'
# mass\core\mass_model.py:1967 UserWarning: No metabolite found for 'tyr__L_c'
# mass\core\mass_model.py:1967 UserWarning: No metabolite found for 'uacgam_c'
# mass\core\mass_model.py:1967 UserWarning: No metabolite found for 'udcpdp'
# mass\core\mass_model.py:1967 UserWarning: No metabolite found for 'udp_c'
# mass\core\mass_model.py:1967 UserWarning: No metabolite found for 'udpglcur_c'
# mass\core\mass_model.py:1967 UserWarning: No metabolite found for 'ura_c'
# mass\core\mass_model.py:1967 UserWarning: No metabolite found for 'uri_c'
# mass\core\mass_model.py:1967 UserWarning: No metabolite found for 'utp_c'
# mass\core\mass_model.py:1967 UserWarning: No metabolite found for 'val__L_c'

# %% [markdown]
# ### Formulate QP minimization for concentrations

# %%
from mass.thermo import (
    ConcSolver, sample_concentrations,
    update_model_with_concentration_solution)

# %%
conc_solver = ConcSolver(
    mass_model,
    excluded_metabolites=["h_c", "h2o_c"],
    constraint_buffer=1,
    equilibrium_reactions=[x.id for x in mass_model.reactions if x.steady_state_flux == 0]

)

conc_solver.setup_feasible_qp_problem(
    fixed_conc_bounds=list(mass_model.fixed),
)

conc_solution = conc_solver.optimize()
conc_solution
# Out:
# <Solution 0.000 at 0x2510e4f0eb0>

# %%
conc_comparison_fig, ax = plt.subplots(nrows=1, ncols=1,
                                       figsize=(5, 5))

plot_comparison(
    x=conc_data["Concentration (mol * L-1)"], y=conc_solution,
    compare="concentrations",
    observable=[mid for mid in conc_data.index], ax=ax,
    legend="right outside", plot_function="loglog",
    xlim=(1e-5, 1e-1), ylim=(1e-5, 1e-1), xy_line=True,
    xy_legend="best", xlabel="Initial [mol/L]", ylabel="Adjusted [mol/L]")

conc_comparison_fig.tight_layout()
update_model_with_concentration_solution(
    mass_model, conc_solution, concentrations=True, Keqs=True, inplace=True);
# Out:
# mass\visualization\visualization_util.py:1202 UserWarning: Ignoring {'gal1p_c', 'val__L_c', 'adocbl', 'gln__L_c', 'mql8', 'clpn161', 'uacgam_c', 'itp_c', 'spmd_c', '5mthf', 'gtp_c', 'phe__L_c', 'pheme', 'adn_c', 'crn_c', 'dgmp_c', 'lys__L_c', 'thmpp', 'glu__L_c', 'skm_c', 'phpyr_c', 'mlthf', 'ctp_c', 'dttp_c', 'pydx5p', 'imp_c', 'met__L_c', 'pe161', 'trp__L_c', 'ura_c', 'dhor__S_c', 'acgam1p_c', 'ser__L_c', 'dtdp_c', 'gthox_c', 'malcoa', 'aps_c', 'tyr__L_c', 'mobd', '2dr5p_c', 'quln_c', 'fad_c', 'cmp_c', 'his__L_c', 'dgsn_c', 'adpglc_c', '4abut_c', 'mnl1p_c', 'chor', 'gmp_c', '2dmmql8', 'mococdp', 'ala_B_c', 'h_c', 'histd_c', 'ala__L_c', 'csn_c', 'clpn160', 'orn_c', 'idp_c', 'glyc__R_c', 'inost_c', 'pro__L_c', 'pe181', 'thf', 'pg181', 'udcpdp', 'hemeO', 'sheme', 'gam6p_c', 'cytd_c', 'man6p_c', '2ddg6p_c', 'cys__L_c', 'datp_c', 'btn', '4hbz_c', 'ile__L_c', 'prpp_c', 'pg161', 'asn__L_c', 'hcys__L_c', 'glcn_c', 'mocogdp', 'gdp_c', 'tre6p_c', 'enter', '10fthf_c', 'udpglcur_c', 'ribflv_c', 'ptrc_c', 'asp__L_c', 'acorn_c', 'sarcs_c', 'thr__L_c', 'arg__L_c', 'h2o_c', '23dhb_c', 'citr__L_c', 'ade_c', 'leu__L_c', 'gua_c', 'aacoa_c', 'hom__L_c', 'damp_c', 'udp_c', 'gsn_c', 'uri_c', 'agm_c', 'hxan_c', 'amet_c', 'camp_c', 'nh4_c', 'fmn_c', 'cbasp_c', 'clpn181', 'f1p_c', 'gly_c', 'utp_c', 'dad_2_c', 'dctp_c', 'gthrd_c', 'pe160', 'pg160', 'anth_c'}, only in one set of given values

# %% [markdown]
# #### Export data for analysis

# %%
conc_data_for_comparison = pd.concat(objs=(conc_data, conc_solution.concentrations), axis=1).dropna()
conc_data_for_comparison.index.name = "ID"
conc_data_for_comparison.columns = ["Initial", "Adjusted"]
conc_data_for_comparison.to_csv("./data/analysis_data/concentrations_extended.csv")
conc_data_for_comparison
# Out:
#             Initial      Adjusted
# ID
# 13dpg_c    0.000055  5.507545e-05
# 2pg_c      0.000725  1.312710e-04
# 3pg_c      0.000138  7.623383e-04
# 6pgc_c     0.000302  1.575748e-03
# ac_c       0.000660  4.405418e+04
# accoa_c    0.000606  4.317167e-02
# acon_C_c   0.000016  2.197753e-05
# actp_c     0.001070  4.437560e-01
# adp_c      0.000656  1.981738e-03
# akg_c      0.000691  1.349778e-04
# amp_c      0.000523  5.228629e-04
# atp_c      0.003740  1.237169e-03
# cit_c      0.000762  1.280359e-03
# co2_c      0.000013  9.326960e+02
# coa_c      0.001370  1.923067e-05
# dhap_c     0.001432  1.756570e-02
# e4p_c      0.000029  2.888189e-05
# f6p_c      0.000364  3.642845e-04
# fdp_c      0.001259  3.797206e-03
# for_c      0.000180  1.800000e-04
# fum_c      0.000594  2.126684e-04
# g1p_c      0.000413  1.436894e-04
# g3p_c      0.000080  2.462581e-05
# g6p_c      0.001029  2.958072e-03
# glyc3p_c   0.000116  3.145473e-06
# hco3_c     0.000175  1.754692e-04
# icit_c     0.000009  3.157041e-05
# mal__L_c   0.001827  6.412006e-04
# nad_c      0.002291  4.625979e-02
# nadh_c     0.000030  1.472093e-06
# nadp_c     0.000012  1.657516e-03
# nadph_c    0.000123  9.118972e-07
# o2_c       0.000440  1.489786e-01
# oaa_c      0.000030  5.891605e-04
# pep_c      0.000383  1.737807e-06
# pi_c       0.010000  1.606113e-02
# ppi_c      0.000500  5.000000e-04
# pyr_c      0.001524  1.092080e-04
# q8_c       0.000231  1.235269e-06
# q8h2_c     0.000099  1.851338e-02
# r5p_c      0.000250  2.244794e-04
# ru5p__D_c  0.000714  2.951011e-04
# s7p_c      0.003899  3.617648e-03
# succ_c     0.001285  1.176567e-04
# succoa_c   0.000233  2.330000e-04
# xu5p__D_c  0.000645  3.864533e-04

# %%
Keq_comparison_fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(5, 5))

plot_comparison(
    x=Keq_data["Equilibrium Constant"], y=conc_solution,
    compare="Keqs", ax=ax,
    legend="right outside", plot_function="loglog",
    xlim=(1e-5, 1e5), ylim=(1e-5, 1e5), xy_line=True,
    xy_legend="best", xlabel="Initial", ylabel="Adjusted")

conc_comparison_fig.tight_layout()
update_model_with_concentration_solution(
    mass_model, conc_solution, concentrations=True, Keqs=True, inplace=True);
# Out:
# mass\visualization\visualization_util.py:1202 UserWarning: Ignoring {'Keq_CHTBStex', 'Keq_ENTCS', 'Keq_UREAtex', 'Keq_THRt4pp', 'Keq_G3PAT141', 'Keq_KDOCT2', 'Keq_NADPPPS', 'Keq_EX_tartr__D_e', 'Keq_XYLUtex', 'Keq_PTA2', 'Keq_THRD_L', 'Keq_FUMtex', 'Keq_FACOAL180t2pp', 'Keq_THIORDXi', 'Keq_OP4ENH', 'Keq_EX_dad_2_e', 'Keq_DAGK160', 'Keq_DXYLONtex', 'Keq_MNLptspp', 'Keq_GLCRt2rpp', 'Keq_PE181abcpp', 'Keq_NDPK7', 'Keq_DURIK1', 'Keq_SELR', 'Keq_G5SADs', 'Keq_PLIPA2A161pp', 'Keq_CYNTAH', 'Keq_DHCINDO', 'Keq_GALURtex', 'Keq_FRUpts2pp', 'Keq_EX_malthx_e', 'Keq_MDDCP2pp', 'Keq_MALTTTRabcpp', 'Keq_PSSA181', 'Keq_RNTR2c2', 'Keq_PLIPA2A181pp', 'Keq_GALCTND', 'Keq_EPMEACPR', 'Keq_MPTSS', 'Keq_3HAD121', 'Keq_HEPT1', 'Keq_CU2tpp', 'Keq_EX_cit_e', 'Keq_2AGPG180tipp', 'Keq_NTP5', 'Keq_EX_fe3dcit_e', 'Keq_AGPAT140', 'Keq_LPLIPAL2ATE180', 'Keq_NTP3', 'Keq_FTHFLi', 'Keq_PRASCSi', 'Keq_CITtex', 'Keq_LPLIPAL1E140pp', 'Keq_GLNS', 'Keq_ABUTD', 'Keq_RBFSa', 'Keq_TYRPtex', 'Keq_AB6PGH', 'Keq_G6Ptex', 'Keq_TYRPpp', 'Keq_OXCOAHDH', 'Keq_THYMtex', 'Keq_LGTHL', 'Keq_CHORS', 'Keq_14GLUCANtexi', 'Keq_AGM3PA', 'Keq_FACOAE120', 'Keq_UGLYCH', 'Keq_THRabcpp', 'Keq_DINSt2pp', 'Keq_GMPS2', 'Keq_PGPP120', 'Keq_EX_15dap_e', 'Keq_ARBTNR3', 'Keq_LPLIPAL1G180pp', 'Keq_ACOATA', 'Keq_PLIPA2G141pp', 'Keq_DAGK120', 'Keq_SELNPS', 'Keq_IMPC', 'Keq_GLYOX3', 'Keq_MPTS', 'Keq_ALAt2pp', 'Keq_XYLUt2pp', 'Keq_CTBTCAL2', 'Keq_DAGK180', 'Keq_EX_etoh_e', 'Keq_TRE6PH', 'Keq_PPCDC', 'Keq_HOMtex', 'Keq_QULNS', 'Keq_CYSDS', 'Keq_EX_leu__L_e', 'Keq_SOTA', 'Keq_MALTabcpp', 'Keq_GP4GH', 'Keq_PROGLYabcpp', 'Keq_OMPDC', 'Keq_EX_ttdcea_e', 'Keq_SPMDabcpp', 'Keq_EX_so4_e', 'Keq_QUIN2tex', 'Keq_EX_3hpp_e', 'Keq_OROTt2_2pp', 'Keq_DTARTD', 'Keq_EX_metsox_R__L_e', 'Keq_ASPO4', 'Keq_SO4tex', 'Keq_EX_ascb__L_e', 'Keq_ECOAH8', 'Keq_ECOAH6', 'Keq_G5SD', 'Keq_GTHOr', 'Keq_CRNCBCT', 'Keq_LACZpp', 'Keq_ICHORS_copy1', 'Keq_NDPK5', 'Keq_3OAR160', 'Keq_PSURIK', 'Keq_EX_ser__D_e', 'Keq_2MAHMP', 'Keq_EX_lys__L_e', 'Keq_ADOCBLtonex', 'Keq_SHGO', 'Keq_UM4PL', 'Keq_PE140abcpp', 'Keq_PPBNGS', 'Keq_UGLT', 'Keq_EAR120x', 'Keq_ALDD3y', 'Keq_ACONIs', 'Keq_ACMANAtex', 'Keq_EX_xylu__L_e', 'Keq_ACGAL1Ptex', 'Keq_PAPA141pp', 'Keq_CA2tex', 'Keq_PAPA180pp', 'Keq_GALCTt2rpp', 'Keq_D_LACtex', 'Keq_ACGAM1PPpp', 'Keq_UDPGALM', 'Keq_EX_3cmp_e', 'Keq_GLCP2', 'Keq_ADOCBLS', 'Keq_S4FE4ST', 'Keq_HG2abcpp', 'Keq_SKMtex', 'Keq_LCTStpp', 'Keq_N2Otex', 'Keq_OGMEACPD', 'Keq_3HAD140', 'Keq_OPHHX3', 'Keq_SO3tex', 'Keq_EX_fusa_e', 'Keq_PGSA160', 'Keq_EX_tyr__L_e', 'Keq_HOMt2pp', 'Keq_CDPPH', 'Keq_H2Otex', 'Keq_LPLIPAL2A181', 'Keq_12PPDStex', 'Keq_EX_spmd_e', 'Keq_LPLIPAL2E120', 'Keq_HXAND', 'Keq_A5PISO', 'Keq_LALGP', 'Keq_NO2tex', 'Keq_ARGAGMt7pp', 'Keq_DM_amob_c', 'Keq_CHLt2pp', 'Keq_PA141abcpp', 'Keq_GPDDA5pp', 'Keq_EX_met__D_e', 'Keq_SO2tex', 'Keq_URIC', 'Keq_CTECOAI6', 'Keq_EX_cpgn_un_e', 'Keq_RFAMPtex', 'Keq_ETHSO3tex', 'Keq_RBFK', 'Keq_SPMDtex', 'Keq_COBALT2tex', 'Keq_DGMPtex', 'Keq_DURIt2pp', 'Keq_EX_his__L_e', 'Keq_IGPS', 'Keq_BGLA1', 'Keq_DMSOR1', 'Keq_DHBSZ3FEabcpp', 'Keq_RNDR4', 'Keq_PSD120', 'Keq_PYK3', 'Keq_CLPNH181pp', 'Keq_EX_fmn_e', 'Keq_ZN2t3pp', 'Keq_LPLIPAL1G161pp', 'Keq_EX_novbcn_e', 'Keq_GUACYC', 'Keq_EX_ppt_e', 'Keq_SHCHD2', 'Keq_EX_fum_e', 'Keq_GLUt2rpp', 'Keq_LPLIPAL1A181pp', 'Keq_F6Pt6_2pp', 'Keq_FRUtex', 'Keq_EX_amp_e', 'Keq_PANTS', 'Keq_LALALGLUtpp', 'Keq_OPMEACPD', 'Keq_ULA4NFT', 'Keq_DMATT', 'Keq_MG2tex', 'Keq_EX_zn2_e', 'Keq_GLCRD', 'Keq_LIPACabcpp', 'Keq_CPGNexs', 'Keq_3OAS180', 'Keq_PYDXtpp', 'Keq_INSt2pp', 'Keq_GGPTRCO', 'Keq_EX_hacolipa_e', 'Keq_HSDy', 'Keq_EX_inost_e', 'Keq_PGSA181', 'Keq_EX_dms_e', 'Keq_GDPtex', 'Keq_SBTtex', 'Keq_FRULYSt2pp', 'Keq_AI2tex', 'Keq_GSNK', 'Keq_PLIPA1G180pp', 'Keq_GLYC3Ptex', 'Keq_GSPMDS', 'Keq_HBZOPT', 'Keq_AMPNTAT', 'Keq_NTPP6', 'Keq_BUTCT', 'Keq_XYHDL', 'Keq_COLIPAabcpp', 'Keq_BUTt2rpp', 'Keq_G3PAT140', 'Keq_UDPGPpp', 'Keq_TMDK1', 'Keq_EX_gbbtn_e', 'Keq_GLYCK2', 'Keq_CTECOAI8', 'Keq_3OAR181', 'Keq_NAt3_2pp', 'Keq_NODOx', 'Keq_EX_thym_e', 'Keq_FHL', 'Keq_HMBS', 'Keq_FEOXAM ...
# C:\Users\dczie\AppData\Local\Temp/ipykernel_17424/3344471432.py:10 UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.

# %% [markdown]
# #### Export data for analysis

# %%
Keq_data_for_comparison = pd.concat(objs=(Keq_data, conc_solution.Keqs), axis=1).dropna()
Keq_data_for_comparison.index.name = "ID"
Keq_data_for_comparison.columns = ["Initial", "Adjusted"]
Keq_data_for_comparison.to_csv("./data/analysis_data/equilibrium_constants_extended.csv")
Keq_data_for_comparison
# Out:
#                    Initial      Adjusted
# ID
# Keq_G3PD5     3.097852e+09  8.369585e+07
# Keq_HCO3E     2.352797e+01  2.352797e+01
# Keq_CS        4.465331e+06  4.465331e+06
# Keq_ICDHyr    7.288431e-01  5.963550e+00
# Keq_ACALD     8.884664e+03  2.003046e+02
# ...                    ...           ...
# Keq_ACONTa    2.777306e-02  4.665965e-02
# Keq_NADH16pp  4.079883e+06  1.764575e+13
# Keq_ETOHtrpp  1.000000e+00  4.730358e-01
# Keq_FDH4pp    1.094655e+12  1.094655e+12
# Keq_SUCCt1pp  2.804840e-05  1.816613e-03
#
# [73 rows x 2 columns]

# %%
# Fix Metabolite IDs as SBML compatible before next step
for metabolite in mass_model.metabolites:
    if metabolite.id[0].isdigit():
        metabolite.id = f"_{metabolite.id}"
mass_model.repair()

# %%
from pprint import pprint
pprint(vars(mass_model.metabolites.co2_c))
# Out:
# {'_annotation': {'bigg.metabolite': ['co2'],
#                  'biocyc': ['META:CARBON-DIOXIDE'],
#                  'chebi': ['CHEBI:23011',
#                            'CHEBI:3283',
#                            'CHEBI:48829',
#                            'CHEBI:16526',
#                            'CHEBI:13283',
#                            'CHEBI:13285',
#                            'CHEBI:13284',
#                            'CHEBI:13282'],
#                  'envipath': ['650babc9-9d68-4b73-9332-11972ca26f7b/compound/2ec3da94-5f50-4525-81b1-5607c5c7a3d3',
#                               '32de3cf4-e3e6-4168-956e-32fa5ddb0ce1/compound/05f60af4-0a3f-4ead-9a29-33bb0f123379'],
#                  'hmdb': ['HMDB01967'],
#                  'inchi_key': ['CURLTUGMZLYLDI-UHFFFAOYSA-N'],
#                  'kegg.compound': ['C00011'],
#                  'kegg.drug': ['D00004'],
#                  'metanetx.chemical': ['MNXM13'],
#                  'reactome.compound': ['29376',
#                                        '5668565',
#                                        '189480',
#                                        '1132345',
#                                        '113528',
#                                        '1237009',
#                                        '159751',
#                                        '389536',
#                                        '159942'],
#                  'sabiork': ['1266'],
#                  'sbo': 'SBO:0000247',
#                  'seed.compound': ['cpd00011']},
#  '_bound': 0.0,
#  '_fixed': True,
#  '_id': 'co2_c',
#  '_initial_condition': 0.001,
#  '_model': <MassModel CentralMetabolism at 0x251106c4f70>,
#  '_reaction': {<MassReaction PPC at 0x251106dc1c0>,
#                <MassReaction PPCK at 0x251106dc3a0>,
#                <MassReaction ME1 at 0x251106dc550>,
#                <MassReaction ME2 at 0x251106dc700>,
#                <MassReaction ICDHyr at 0x251106dd040>,
#                <MassReaction AKGDH at 0x251106dd280>,
#                <MassReaction HCO3E at 0x251106df580>,
#                <MassReaction CO2tpp at 0x251106df700>,
#                <MassReaction POX at 0x251106e2a30>,
#                <MassReaction PDH at 0x251106e9d60>,
#                <MassReaction OAADC at 0x251106e9f40>,
#                <MassReaction GND at 0x251106eaee0>},
#  'charge': 0,
#  'compartment': 'c',
#  'formula': 'CO2',
#  'name': 'CO2 CO2',
#  'notes': {'original_bigg_ids': ['co2_c']}}

# %%
#Set the metabolite for CO2 as a fixed metabolite using the "fixed" attribute (e.g., co2_c.fixed = True, etc.)
mass_model.metabolites.co2_c.fixed = True
mass_model.metabolites.co2_c.initial_condition = 0.001

# %%
n_models = 2

# %%
conc_solver = ConcSolver(
    mass_model,
    excluded_metabolites=["h_c", "h2o_c"],
    constraint_buffer=1,
    equilibrium_reactions=[x.id for x in mass_model.reactions if x.steady_state_flux == 0]

)

conc_solver.setup_sampling_problem(
    fixed_conc_bounds=list(mass_model.fixed),
)
for variable in conc_solver.variables:
    try:
        met = mass_model.metabolites.get_by_id(variable.name)
        variable.lb, variable.ub = np.log([met.ic / 10, met.ic * 10])
    except:
        pass
conc_samples = sample_concentrations(conc_solver, n=n_models, seed=4)
conc_samples
# Out:
# ---------------------------------------------------------------------------
# OptimizationError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17424/1581518266.py in <cell line: 18>()
#      16     except:
#      17         pass
# ---> 18 conc_samples = sample_concentrations(conc_solver, n=n_models, seed=4)
#      19 conc_samples
#
# c:\users\dczie\appdata\local\programs\python\python38\lib\site-packages\mass\thermo\conc_sampling\conc_sampling.py in sample_concentrations(concentration_solver, n, method, thinning, processes, seed)
#      70     """
#      71     if method == "optgp":
# ---> 72         sampler = ConcOptGPSampler(
#      73             concentration_solver, processes=processes, thinning=thinning, seed=seed
#      74         )
#
# c:\users\dczie\appdata\local\programs\python\python38\lib\site-packages\mass\thermo\conc_sampling\conc_optgp.py in __init__(self, concentration_solver, processes, thinning, nproj, seed)
#     172             concentration_solver, thinning, nproj=nproj, seed=seed
#     173         )
# --> 174         self.generate_cva_warmup()
#     175
#     176         if processes is None:
#
# c:\users\dczie\appdata\local\programs\python\python38\lib\site-packages\mass\thermo\conc_sampling\conc_hr_sampler.py in generate_cva_warmup(self)
#     231         self.warmup = self.warmup[0 : self.n_warmup, :]
#     232         if self.warmup.size == 0:
# --> 233             raise OptimizationError(
#     234                 "CVA warmup found no feasible solutions. Ensure the systems "
#     235                 "has the appropriate variables and constraints by excluding "
#
# OptimizationError: CVA warmup found no feasible solutions. Ensure the systems has the appropriate variables and constraints by excluding certain metabolites (e.g. hydrogen) and reactions (e.g. boundary reactions), and by indicating the equilibrium reactions.

# %% [markdown]
# ### Balance network with pseudoreactions and calculate PERCs

# %%
models_for_ensemble = []
for idx, conc_sample in conc_samples.iterrows():
    # Make copy of new model
    new_model = mass_model.copy()
    new_model.id += "_C{0:d}".format(idx)
    print(f"Creating model {new_model.id}")
    # Get concentration sample and update model with sample
    new_model.update_initial_conditions(conc_sample.to_dict())
    fluxes = np.array(list(new_model.steady_state_fluxes.values()))
    imbalanced_metabolites = new_model.S.dot(fluxes)
    # Iterate through metabolites
    for mid, imbalance in imbalanced_metabolites.iteritems():
        # Ignore balanced metabolites
        if imbalance == 0:
            continue
        # Get metabolite object
        met = new_model.metabolites.get_by_id(mid)

        # Add boundary reactions for imbalanced metabolites
        boundary_type = "sink"    
        # Add boundary reaction with imbalance as flux value
        boundary_reaction = new_model.add_boundary(
            mid, boundary_type, boundary_condition=met.ic)

        boundary_reaction.Keq = 1
        if imbalance < 0:
            boundary_reaction.reverse_stoichiometry(inplace=True)
            imbalance = -imbalance

        boundary_reaction.kf = imbalance / met.ic
        boundary_reaction.steady_state_flux = imbalance
        try:
            # Update PERCs
            new_model.calculate_PERCs(
                fluxes={
                    r: v for r, v in new_model.steady_state_fluxes.items()
                    if not r.boundary},
                update_reactions=True)
        except:
            print("Negative PERCs for {0}".format(new_model.id))
            continue
    models_for_ensemble.append(new_model)
print("Number of models in ensemble: {0:d}".format(
    len(models_for_ensemble)))
# Out:
# Creating model CentralMetabolism_C0
# Creating model CentralMetabolism_C1
# Number of models in ensemble: 2

# %%
reference_model = models_for_ensemble[0].copy()
reference_model.id = "Glycolysis_Ref_wo_Enzymes"
sim = Simulation(reference_model)
sim.integrator.absolute_tolerance = 1e-15
sim.integrator.relative_tolerance = 1e-9

tfinal = 1e6
conc_sol_orig, flux_sol_orig = sim.simulate(reference_model, time=(0, tfinal))
conc_sol_orig.view_time_profile()

# %%
conc_sol_pert, flux_sol_pert = sim.simulate(
    reference_model, time=(0, tfinal), perturbations={"kf_CS": "kf_CS * 0.05"})
conc_sol_pert.view_time_profile()

# %%
#Citrate should deplete
print("Citrate WT is: " + str(conc_sol_orig.cit_c[-1]))
print("Citrate with CS inhibited is: " + str(conc_sol_pert.cit_c[-1]))

#succoa should deplete
print("Succoa WT is: " + str(conc_sol_orig.succoa_c[-1]))
print("Succoa with CS inhibited is: " + str(conc_sol_pert.succoa_c[-1]))

#Malate should accumulate
print("Malate WT is: " + str(conc_sol_orig.mal__L_c[-1]))
print("Malate with CS inhibited is: " + str(conc_sol_pert.mal__L_c[-1]))

#accoa should accumulate
print("Accoa original is: " + str(conc_sol_orig.accoa_c[-1]))
print("Accoa original is: " + str(conc_sol_pert.accoa_c[-1]))
# Out:
# Citrate WT is: 0.0020582786930587746
# Citrate with CS inhibited is: 0.00020266784883631828
# Succoa WT is: 0.00016616005608121895
# Succoa with CS inhibited is: 6.43026469187652e-05
# Malate WT is: 0.00042559343475320516
# Malate with CS inhibited is: 0.0002490542373391568
# Accoa original is: 0.054715005586985124
# Accoa original is: 0.07487970128718137

# %% [markdown]
# #### Save a reference MASS model w/o enzymes

# %%
conc_sol, flux_sol = sim.find_steady_state(
    models=reference_model, strategy="simulate", 
    tfinal=tfinal)
if conc_sol and flux_sol:
    reference_model.update_initial_conditions(conc_sol)
    reference_model.update_parameters({f"v_{k}": v for k, v in flux_sol.items()})
    # Save a reference MASS model
    save_mass_json_model(
        mass_model=reference_model,
        filename=f"./models/mass/without_enzymes/{reference_model.id}.json")
    print(f"Saving {reference_model.id}")
reference_model
# Out:
# Saving Glycolysis_Ref_wo_Enzymes
# <MassModel Glycolysis_Ref_wo_Enzymes at 0x1b6926d56d0>

# %% [markdown]
# ## Create Enzyme Modules
#
# Assume 90% of flux goes through the major isozyme, the remaining through the minor isozyme

# %%
from construction_functions import make_enzyme_module_from_dir

# %%
isozyme1_percent = 0.9
isozyme2_percent = 0.1

# Isozymes and flux split percentages,
isozymes_and_flux_splits = {
    "PFK": {
        "PFK1": isozyme1_percent,
        "PFK2": isozyme2_percent,
    },
    "FBP": {
        "FBP1": isozyme1_percent,
        "FBP2": isozyme2_percent,
    },
    "FBA": {
        "FBA1": isozyme1_percent,
        "FBA2": isozyme2_percent,
    },
    "PGM": {
        "PGMi": isozyme1_percent,
        "PGMd": isozyme2_percent,
    },
    "PYK": {
        "PYK1": isozyme1_percent,
        "PYK2": isozyme2_percent,
    },
}
        
isozymes_and_flux_splits
# Out:
# {'PFK': {'PFK1': 0.9, 'PFK2': 0.1},
#  'FBP': {'FBP1': 0.9, 'FBP2': 0.1},
#  'FBA': {'FBA1': 0.9, 'FBA2': 0.1},
#  'PGM': {'PGMi': 0.9, 'PGMd': 0.1},
#  'PYK': {'PYK1': 0.9, 'PYK2': 0.1}}

# %%
final_ensemble = []
for model in models_for_ensemble:
    enzyme_modules = {}
    for reaction in model.reactions.get_by_any(reaction_list):
        # PGM & PGK needs flux flipped since enzyme module stoichiometry
        # is reversed compared to lone reaction.
        if reaction.id in ["PGK", "PGM"]:
            flux = -reaction.steady_state_flux
        else:
            flux = reaction.steady_state_flux
        # Make isozymes
        if reaction.id in isozymes_and_flux_splits:
            isozymes_and_flux_split = isozymes_and_flux_splits[reaction.id]
            isozyme_modules = []
            for isozyme, flux_split in isozymes_and_flux_split.items():
                enzyme_module = make_enzyme_module_from_dir(
                    enzyme_id=isozyme,
                    steady_state_flux=flux * flux_split, # Split flux for isozymes
                    metabolite_concentrations=model.initial_conditions,
                    path_to_dir="./data/enzyme_module_data",
                    kcluster=1,
                    enzyme_gpr=reaction.gene_reaction_rule,
                    zero_tol=1e-10)
                isozyme_modules += [enzyme_module]
            enzyme_modules[reaction] = isozyme_modules
        else:
            enzyme_module = make_enzyme_module_from_dir(
                enzyme_id=reaction.id,
                steady_state_flux=flux,
                metabolite_concentrations=new_model.initial_conditions,
                path_to_dir="./data/enzyme_module_data",
                kcluster=1,
                enzyme_gpr=reaction.gene_reaction_rule,
                zero_tol=1e-10)
            enzyme_modules[reaction] = [enzyme_module]
    for reaction_to_remove, enzymes_to_add in enzyme_modules.items():
        model.remove_reactions([reaction_to_remove])
        for enzyme in enzymes_to_add:
            model = model.merge(enzyme, inplace=True)
    final_ensemble += [model]
    print(f"Finished {model.id}")
# Out:
# Finished Glycolysis_C0
# Finished Glycolysis_C1
# Finished Glycolysis_C2
# Finished Glycolysis_C3
# Finished Glycolysis_C4

# %% [markdown]
# # Inspect a model

# %%
reference_model = models_for_ensemble[0].copy()
reference_model.id = "Glycolysis_Ref_w_Enzymes"
sim = Simulation(reference_model)
sim.integrator.absolute_tolerance = 1e-15
sim.integrator.relative_tolerance = 1e-9

tfinal = 1e6
conc_sol, flux_sol = sim.simulate(reference_model, time=(0, tfinal))
conc_sol.view_time_profile(plot_function="semilogx")

# %% [markdown]
# #### Save a reference MASS model w/ enzymes

# %%
conc_sol, flux_sol = sim.find_steady_state(
    models=reference_model, strategy="simulate", update_values=True,
    tfinal=tfinal)
if conc_sol and flux_sol:
    # Save a reference MASS model
    save_mass_json_model(
        mass_model=reference_model,
        filename=f"./models/mass/with_enzymes/{reference_model.id}.json")
    print(f"Saving {reference_model.id}")
reference_model
# Out:
# Saving Glycolysis_Ref_w_Enzymes
# <MassModel Glycolysis_Ref_w_Enzymes at 0x1b692ddde50>

# %% [markdown]
# ## Simulate to steady state and export ensemble

# %%
sim = Simulation(final_ensemble[0])
sim.integrator.absolute_tolerance = 1e-15
sim.integrator.relative_tolerance = 1e-9
sim.add_models(final_ensemble[1:], disable_safe_load=True)
for model in final_ensemble:
    # Attempt to determine steady state
    conc_sol, flux_sol = sim.find_steady_state(
        models=model, strategy="simulate", update_values=True,
        tfinal=tfinal)
    if conc_sol and flux_sol:
        # Save a reference MASS model
        save_mass_json_model(
            mass_model=model,
            filename=f"./models/mass/with_enzymes/{model.id}.json")
        print(f"Saving {model.id}")
    else:
        print(f"No steady state for {model.id}.")
# Out:
# Saving Glycolysis_C0
# Saving Glycolysis_C1
# Saving Glycolysis_C2
# Saving Glycolysis_C3
# Saving Glycolysis_C4
